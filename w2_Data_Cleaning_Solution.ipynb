# %% [markdown]
# <a href="https://colab.research.google.com/github/Emiliewu/ds-study-materials/blob/main/w2_Data_Cleaning_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Cleaning**
# - **Coding Dojo**
# - **Course 1 - Fundamentals**
# - **Week 2 - Lecture 2**

# %% [markdown]
# # **Code Along**

# %% [markdown]
# ### **Task**
# - Load the data
# - Inspect the data
# - Clean the data

# %% [markdown]
# ## **Import Libraries**

# %%
## Pandas
import pandas as pd
## Numpy
import numpy as np
## Seaborn
import seaborn as sns

# %% [markdown]
# ## **Load the Data**

# %%
## Load Data
df = sns.load_dataset('titanic')

# %% [markdown]
# ## **Inspect the Data**

# %% [markdown]
# ### **head()**

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# - The data appears to have loaded correctly.

# %% [markdown]
# ### **shape()**

# %%
## Display the number of rows and columns for the dataframe
## Using a print() and an F-string:
## 'There are x rows, and x columns.'
print(f'There are {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
# There are 891 rows and 15 columns.

# %% [markdown]
# ### **dtypes**

# %%
## Display the column names and datatypes for each column
## Columns with mixed datatypes are identified as an object datatype
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# ### **info()**

# %%
## Display the column names, count of non-null values, and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### **describe()**

# %%
## Display the descriptive statistics for the numeric columns
## Using include="number"
df.describe(include="number")
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
## Display the descriptive statistics for the object columns
## Using include="object"
df.describe(include="object")
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Clean the Data**

# %% [markdown]
# ### **Remove Unnecessary Columns**

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# **Columns to remove:**
# - 'embarked' duplicates the 'embark_town' column
# - 'adult_male' datas is contained the 'who' column
# - 'alive' column duplicates the 'survived' column

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### **Drop a Single Column**

# %%
## Drop a single column
df.drop(columns = 'embarked', inplace = True)

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %% [markdown]
# - Confirmed, the column has been dropped.

# %% [markdown]
# #### **Drop Multiple Columns**

# %%
## Drop multiple columns
## Note a list of columns is passed instead of a single string
df.drop(columns = ['adult_male', 'alive'], inplace = True)

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who deck  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man  NaN
# 1         1       1  female  38.0      1      0  71.2833  First  woman    C
# 2         1       3  female  26.0      0      0   7.9250  Third  woman  NaN
# 3         1       1  female  35.0      1      0  53.1000  First  woman    C
# 4         0       3    male  35.0      0      0   8.0500  Third    man  NaN
#
#    embark_town  alone
# 0  Southampton  False
# 1    Cherbourg  False
# 2  Southampton   True
# 3  Southampton  False
# 4  Southampton   True

# %% [markdown]
# - Confirmed, columns have been dropped.

# %% [markdown]
# ### **Remove Unecessary Rows**

# %% [markdown]
# #### **Duplicates**

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
## Display the number of duplicate rows in the dataset
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 107 duplicate rows.

# %%
## Create a filter of duplicated rows ('False', 'first', or 'last')
duplicated_filter = df.duplicated(keep = 'last')

# %%
## Display the 'last' duplicated rows
df[duplicated_filter]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# 26          0       3    male   NaN      0      0   7.2250   Third    man
# 28          1       3  female   NaN      0      0   7.8792   Third  woman
# 29          0       3    male   NaN      0      0   7.8958   Third    man
# 32          1       3  female   NaN      0      0   7.7500   Third  woman
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 739         0       3    male   NaN      0      0   7.8958   Third    man
# 784         0       3    male  25.0      0      0   7.0500   Third    man
# 792         0       3  female   NaN      8      2  69.5500   Third  woman
# 795         0       2    male  39.0      0      0  13.0000  Second    man
# 832         0       3    male   NaN      0      0   7.2292   Third    man
#
#     deck  embark_town  alone
# 4    NaN  Southampton   True
# ...

# %%
## Drop duplicate rows
df = df.drop_duplicates()

# %%
## Confirm duplicate rows have been dropped
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %% [markdown]
# ### **Inspect Column Datatypes for Errors**

# %% [markdown]
# - Check the data types of the dataframe using df.dtypes or df.info()

# %%
## Display column names and datatypes
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# class          category
# who              object
# deck           category
# embark_town      object
# alone              bool
# dtype: object

# %%
## Display the column names, count of non-null values, and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 784 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int64
#  1   pclass       784 non-null    int64
#  2   sex          784 non-null    object
#  3   age          678 non-null    float64
#  4   sibsp        784 non-null    int64
#  5   parch        784 non-null    int64
#  6   fare         784 non-null    float64
#  7   class        784 non-null    category
#  8   who          784 non-null    object
#  9   deck         202 non-null    category
#  10  embark_town  782 non-null    object
#  11  alone        784 non-null    bool
# dtypes: bool(1), category(2), float64(2), int64(4), object(3)
# memory usage: 64.0+ KB

# %% [markdown]
# - All collumns appear to have the appropriate data types.

# %% [markdown]
# ### **Inspect Column Names for Errors**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.(example: cat, Cat, cats)

# %%
## Display column names
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'class',
#        'who', 'deck', 'embark_town', 'alone'],
#       dtype='object')

# %% [markdown]
# - No errors noted.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Inspect Values for Errors**

# %% [markdown]
# #### **Numeric Columns**

# %% [markdown]
# - **Check for unusual or impossible values.**
#  - Example a weight, or height that is negative in value.
#
# - **Check for Outliers**
#
#  - Outliers are values that are extremely higher or lower than all of the other values in that feature. In general, outliers should not be removed unless you have reason to believe it is an error in the dataset. It is important to investigate outliers, as some models are very sensitive to outliers.

# %%
## Display the descriptive statistics for the non-numeric columns
df.describe(include="number")
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  784.000000  784.000000  678.000000  784.000000  784.000000  784.000000
# mean     0.411990    2.243622   29.869351    0.522959    0.415816   34.711740
# std      0.492507    0.855056   14.759076    0.986231    0.836922   52.160151
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   28.250000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000   39.000000    1.000000    1.000000   34.109350
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# - **Fare**
#   - 512.3292 does appear to be high even for the max value.

# %% [markdown]
# #### **Categorical Columns**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.(example: cat, Cat, cats)

# %%
# Create a series of the datatypes
data_types = df.dtypes
# Create a filter to select only the object datatypes
object_data_types = data_types[(data_types == "object")]
# Display the series of object datatypes
object_data_types
# Out:
# sex            object
# who            object
# embark_town    object
# dtype: object

# %%
## Display the index of object datatypes
object_data_types.index
# Out:
# Index(['sex', 'who', 'embark_town'], dtype='object')

# %%
## Loop through the index of object_data_types 
for column in object_data_types.index:
    # Display the unique values from the column
    print(column)
    print(df[column].unique())
    print('\n')
# Out:
# sex
# ['male' 'female']
#
#
# who
# ['man' 'woman' 'child']
#
#
# embark_town
# ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
# Create a series of the datatypes
data_types = df.dtypes
# Create a filter to select only the object datatypes
object_data_types = data_types[(data_types == "object")]
# Display the series of object datatypes
object_data_types
# Out:
# sex            object
# who            object
# embark_town    object
# dtype: object

# %% [markdown]
# ##### **'sex' column**

# %%
# Display the unique values from the column
print(df['sex'].unique())
# Out:
# ['male' 'female']

# %%
df['sex'].value_counts()
# Out:
# male      491
# female    293
# Name: sex, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'class' column**

# %%
# Display the unique values from the column
print(df['class'].unique())
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df['class'].value_counts()
# Out:
# Third     405
# First     214
# Second    165
# Name: class, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'who' column**

# %%
# Display the unique values from the column
print(df['who'].unique())
# Out:
# ['man' 'woman' 'child']

# %%
df['who'].value_counts()
# Out:
# man      451
# woman    251
# child     82
# Name: who, dtype: int64

# %% [markdown]
# - No issues noted.

# %% [markdown]
# ##### **'embark_town' column**

# %%
# Display the unique values from the column
print(df['embark_town'].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
df['embark_town'].value_counts()
# Out:
# Southampton    568
# Cherbourg      155
# Queenstown      59
# Name: embark_town, dtype: int64

# %% [markdown]
# - Change Southhampton to SH, Cherbourg to CB and Queenstown to QT using the .replace function.

# %%
## Method 1 - Use Lists to replace values
# df.replace(['Southampton', 'Cherbourg', 'Queenstown'], ['SH', 'CB', 'QT'], inplace = True)

## Method 2 - Use a Dictionary to replace values
df.replace({'Southampton': 'SH', 'Cherbourg': 'CB', 'Queenstown': 'QT'}, inplace = True)

# %%
df['embark_town'].value_counts()
# Out:
# SH    568
# CB    155
# QT     59
# Name: embark_town, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# - We could use .info() to see if there are any missing values, however it is best practice to use .isna()

# %%
## Display the total number of missing values
print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 690 missing values.

# %%
## Display the count of missing values by column
print(df.isna().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# deck           582
# embark_town      2
# alone            0
# dtype: int64

# %%
## Display the percentage of missing values by column
print(df.isna().sum()/len(df)*100)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            13.520408
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# class           0.000000
# who             0.000000
# deck           74.234694
# embark_town     0.255102
# alone           0.000000
# dtype: float64

# %%
## Diplays only rows with nan values
df[df.isna().any(axis = 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class    who  \
# 0           0       3    male  22.0      1      0   7.2500   Third    man
# 2           1       3  female  26.0      0      0   7.9250   Third  woman
# 4           0       3    male  35.0      0      0   8.0500   Third    man
# 5           0       3    male   NaN      0      0   8.4583   Third    man
# 7           0       3    male   2.0      3      1  21.0750   Third  child
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 882         0       3  female  22.0      0      0  10.5167   Third  woman
# 883         0       2    male  28.0      0      0  10.5000  Second    man
# 885         0       3  female  39.0      0      5  29.1250   Third  woman
# 888         0       3  female   NaN      1      2  23.4500   Third  woman
# 890         0       3    male  32.0      0      0   7.7500   Third    man
#
#     deck embark_town  alone
# 0    NaN          SH  False
# ...

# %% [markdown]
# #### **Missing Value Option Justifications**

# %% [markdown]
# ##### **Numeric Columns**

# %% [markdown]
# **Drop the column**
# - con: This would result in a significant loss of data.
# - +50% missing values per row would be significant enough to justify this option.
#
# **Drop rows with missing values**
# - con: This would result in a significant loss of data.
# - +5% missing values per column would too great to justify this option, however -5% missing values would justify this option.
#
# **Impute missing values using the 'mean' value of the column**
# - pro: This typically works well with small numeric datasets.
# - con: This can introduce bias and is affected by skew and outliers more than the 'median' value.
# - con: This will not factor correlations between features.
#
# **Impute missing values using the 'median' value of the column**
# - pro: This typically works well with small numeric datasets.
# - pro: This is less affected by outliers than strategy = 'mean'.
# - con: This will not factor correlations between features.

# %% [markdown]
# ##### **Categorical Columns**

# %% [markdown]
# **Drop the column**
# - con: This would result in a significant loss of data.
# - +50% missing values per row would be significant enough to justify this option.
#
# **Drop rows with missing values**
# - con: This would result in a significant loss of data.
# - +5% missing values per column would too great to justify this option, however -5% missing values would justify this option.
#
# **Replace missing values with the value 'Unknown'**
# - pro: This typically will not create bias in favor of a specific label or class.
# - con: This will not factor correlations between features.
#
# **Impute missing values using the most frequent value, 'mode', value of the column**
# - pro: This typically works well with small numeric datasets.
# - con: This may create bias in favor of a specific label or class.
# - con: This will not factor correlations between features.

# %% [markdown]
# #### **'age' Column**

# %% [markdown]
# - **Missing 13.52% of values**
# - **Strategy:**
#  - Replace missing values with the median value of the column
# - **Justification**
#   - This is less affected by outliers than strategy = 'mean'.

# %% [markdown]
# ##### **Replace the missing values with the column's 'median' value**

# %%
## Define the median value of the column
median_age = df['age'].median()

# %%
## Replace the missing values with the column's 'median' value
df['age'].fillna(value = median_age, inplace = True)

# %% [markdown]
# #### **'deck' Column**

# %% [markdown]
# - **Missing 74.23% of values**
# - **Strategy:**
#  - Drop the column
# - **Justification**
#   -  +50% missing values per row would be significant enough to justify this.

# %% [markdown]
# ##### **Drop the column**

# %%
## Drop a single column
df.drop(columns = 'deck', inplace = True)

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#   embark_town  alone
# 0          SH  False
# 1          CB  False
# 2          SH   True
# 3          SH  False
# 4          SH   True

# %% [markdown]
# - Confirmed, the column has been dropped.

# %%
## Display the total number of missing values
print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 2 missing values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **Challenge**

# %% [markdown]
# ### **Task**
# - Load the data
# - Inspect the data
# - Clean the data
# - Explore the Data

# %% [markdown]
# - We will use data on the Super Bowls. You can download the data [here](https://drive.google.com/file/d/1kWqIFO9LgVlMsYG9M9boRKCFiizpUB5o/view?usp=sharing).

# %% [markdown]
# ## **Load the Data**

# %%
file_url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vSAwjsA-rwGlz_Bb0yIgC13scmhxQCjayvh-sp0v3lRMxejeem8ntBBcDpr4xbNNMiGzB8VGPKJzGJv/pub?output=csv"

# %%
## Load Data
df = pd.read_csv(file_url)

# %% [markdown]
# ## **Inspect the Data**

# %% [markdown]
# ### **head()**

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    Unnamed: 0       Date   SB  Attendance                    QB  Winner  \
# 0           0  15-Jan-67    I       61946                    Bart Starr
# 1           1  14-Jan-68   II       75546                    Bart Starr
# 2           2  12-Jan-69  III       75389                    Joe Namath
# 3           3  11-Jan-70   IV       80562   Len Dawson, Mike Livingston
# 4           4  17-Jan-71    V       79204  Earl Morrall , Johnny Unitas
#
#      Coach Winner              Winner  Winning Pts  \
# 0  Vince Lombardi   Green Bay Packers           35
# 1  Vince Lombardi   Green Bay Packers           33
# 2     Weeb Ewbank       New York Jets           16
# 3      Hank Stram  Kansas City Chiefs           23
# 4  Don McCafferty     Baltimore Colts           16
#
#                       QB Loser Coach Loser  ...         City       State  \
# 0                   Len Dawson  Hank Stram  ...  Los Angeles  California
# 1              Daryle Lamonica  John Rauch  ...        Miami     Florida
# ...

# %% [markdown]
# - The data appears to have loaded correctly.

# %% [markdown]
# ### **shape()**

# %%
## Display the number of rows and columns for the dataframe
df.shape
print(f'There are {df.shape[0]} rows, and {df.shape[1]} columns.')
print(f'The rows represent {df.shape[0]} observations, and the columns represent {df.shape[1]-1} features and 1 target variable to predict.')
# Out:
# There are 53 rows, and 24 columns.
# The rows represent 53 observations, and the columns represent 23 features and 1 target variable to predict.

# %% [markdown]
# ### **dtypes()**

# %%
## Display the column names and datatypes for each column
## Columns with mixed datatypes are identified as an object datatype
df.dtypes
# Out:
# Unnamed: 0           int64
# Date                object
# SB                  object
# Attendance           int64
# QB  Winner          object
# Coach Winner        object
# Winner              object
# Winning Pts          int64
# QB Loser            object
# Coach Loser         object
# Loser               object
# Losing Pts           int64
# MVP                 object
# Stadium             object
# City                object
# State               object
# Point Difference     int64
# Referee             object
# Umpire              object
# Head Linesman       object
# Line Judge          object
# Field Judge         object
# Back Judge          object
# Side Judge          object
# dtype: object

# %% [markdown]
# ### **info()**

# %%
## Display the column names, count of non-null values, and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        53 non-null     int64
#  1   Date              53 non-null     object
#  2   SB                53 non-null     object
#  3   Attendance        53 non-null     int64
#  4   QB  Winner        53 non-null     object
#  5   Coach Winner      53 non-null     object
#  6   Winner            53 non-null     object
#  7   Winning Pts       53 non-null     int64
#  8   QB Loser          53 non-null     object
#  9   Coach Loser       53 non-null     object
#  10  Loser             53 non-null     object
#  11  Losing Pts        53 non-null     int64
#  12  MVP               53 non-null     object
#  13  Stadium           53 non-null     object
#  14  City              53 non-null     object
#  15  State             53 non-null     object
# ...

# %% [markdown]
# ### **describe()**

# %%
## Display the descriptive statistics for the numeric columns
## include="number"
df.describe(include="number")
# Out:
#        Unnamed: 0     Attendance  Winning Pts  Losing Pts  Point Difference
# count   53.000000      53.000000    53.000000   53.000000         53.000000
# mean    26.018868   77901.358491    30.584906   16.452830         14.132075
# std     15.476397   10773.028620     9.636537    7.252496         10.412710
# min      0.000000   61946.000000    14.000000    3.000000          1.000000
# 25%     13.000000   71525.000000    24.000000   10.000000          5.000000
# 50%     26.000000   74107.000000    31.000000   17.000000         12.000000
# 75%     39.000000   80562.000000    35.000000   21.000000         19.000000
# max     53.000000  103985.000000    55.000000   33.000000         45.000000

# %%
## Display the descriptive statistics for the numeric columns
## include="object"
df.describe(include="object")
# Out:
#              Date   SB QB  Winner Coach Winner               Winner  \
# count          53   53         53           53                   53
# unique         52   52         33           40                   22
# top     25-Jan-87  XXI  Tom Brady   Chuck Noll  Pittsburgh Steelers
# freq            2    2          5            4                    6
#
#           QB Loser Coach Loser           Loser        MVP    Stadium  \
# count           53          53              53         53         53
# unique          40          39              26         44         31
# top     John Elway   Don Shula  Denver Broncos  Tom Brady  Rose Bowl
# freq             4           4               6          4          6
#
#                City    State          Referee       Umpire  Head Linesman  \
# count            53       53               49           49             48
# unique           20       11               30           26             27
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## **Clean the Data**

# %% [markdown]
# ### **Remove Unnecessary Columns**

# %%
## Display the first (2) rows of the dataframe
df.head(2)
# Out:
#    Unnamed: 0       Date  SB  Attendance  QB  Winner    Coach Winner  \
# 0           0  15-Jan-67   I       61946  Bart Starr  Vince Lombardi
# 1           1  14-Jan-68  II       75546  Bart Starr  Vince Lombardi
#
#               Winner  Winning Pts         QB Loser Coach Loser  ...  \
# 0  Green Bay Packers           35       Len Dawson  Hank Stram  ...
# 1  Green Bay Packers           33  Daryle Lamonica  John Rauch  ...
#
#           City       State Point Difference Referee Umpire Head Linesman  \
# 0  Los Angeles  California               25     NaN    NaN           NaN
# 1        Miami     Florida               19     NaN    NaN           NaN
#
#    Line Judge Field Judge Back Judge Side Judge
# 0         NaN         NaN        NaN        NaN
# 1         NaN         NaN        NaN        NaN
#
# [2 rows x 24 columns]

# %% [markdown]
# **Columns to remove:**
# - 'Unnamed: 0' duplicates the index

# %%
## Display the first (5) rows of the dataframe
df.head()
# Out:
#    Unnamed: 0       Date   SB  Attendance                    QB  Winner  \
# 0           0  15-Jan-67    I       61946                    Bart Starr
# 1           1  14-Jan-68   II       75546                    Bart Starr
# 2           2  12-Jan-69  III       75389                    Joe Namath
# 3           3  11-Jan-70   IV       80562   Len Dawson, Mike Livingston
# 4           4  17-Jan-71    V       79204  Earl Morrall , Johnny Unitas
#
#      Coach Winner              Winner  Winning Pts  \
# 0  Vince Lombardi   Green Bay Packers           35
# 1  Vince Lombardi   Green Bay Packers           33
# 2     Weeb Ewbank       New York Jets           16
# 3      Hank Stram  Kansas City Chiefs           23
# 4  Don McCafferty     Baltimore Colts           16
#
#                       QB Loser Coach Loser  ...         City       State  \
# 0                   Len Dawson  Hank Stram  ...  Los Angeles  California
# 1              Daryle Lamonica  John Rauch  ...        Miami     Florida
# ...

# %% [markdown]
# #### **Drop a Single Column**

# %%
## Drop a single column
df.drop(columns = 'Unnamed: 0', inplace = True)

# %%
## Display the first (2) rows of the dataframe
df.head(2)
# Out:
#         Date  SB  Attendance  QB  Winner    Coach Winner             Winner  \
# 0  15-Jan-67   I       61946  Bart Starr  Vince Lombardi  Green Bay Packers
# 1  14-Jan-68  II       75546  Bart Starr  Vince Lombardi  Green Bay Packers
#
#    Winning Pts         QB Loser Coach Loser               Loser  ...  \
# 0           35       Len Dawson  Hank Stram  Kansas City Chiefs  ...
# 1           33  Daryle Lamonica  John Rauch     Oakland Raiders  ...
#
#           City       State Point Difference Referee Umpire  Head Linesman  \
# 0  Los Angeles  California               25     NaN    NaN            NaN
# 1        Miami     Florida               19     NaN    NaN            NaN
#
#   Line Judge Field Judge Back Judge Side Judge
# 0        NaN         NaN        NaN        NaN
# 1        NaN         NaN        NaN        NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# - Confirmed, the column has been dropped.

# %% [markdown]
# ### **Remove Unecessary Rows**

# %% [markdown]
# #### **Duplicates**

# %%
## Display the number of duplicate rows in the dataset
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 1 duplicate rows.

# %%
## Create a filter of duplicated rows ('False', 'first', or 'last')
duplicated_filter = df.duplicated(keep = 'last')

# %%
## Display the 'last' duplicated rows
df[duplicated_filter]
# Out:
#          Date   SB  Attendance  QB  Winner   Coach Winner           Winner  \
# 20  25-Jan-87  XXI      101063  Phil Simms  Bill Parcells  New York Giants
#
#     Winning Pts    QB Loser Coach Loser           Loser  ...      City  \
# 20           39  John Elway  Dan Reeves  Denver Broncos  ...  Pasadena
#
#          State Point Difference          Referee        Umpire  Head Linesman  \
# 20  California               19  Jerry Markbreit  Bob Boylston   Terry Gierke
#
#    Line Judge   Field Judge Back Judge Side Judge
# 20  Bob Beeks  Pat Mallette  Jim Poole   Gil Mace
#
# [1 rows x 23 columns]

# %%
## Drop duplicate rows
df = df.drop_duplicates()

# %%
## Confirm duplicate rows have been dropped
print(f'There are {df.duplicated().sum()} duplicate rows.')
# Out:
# There are 0 duplicate rows.

# %% [markdown]
# ### **Inspect Column Datatypes for Errors**

# %% [markdown]
# - Check the data types of the dataframe using df.dtypes or df.info()

# %%
## Display column names and datatypes
df.dtypes
# Out:
# Date                object
# SB                  object
# Attendance           int64
# QB  Winner          object
# Coach Winner        object
# Winner              object
# Winning Pts          int64
# QB Loser            object
# Coach Loser         object
# Loser               object
# Losing Pts           int64
# MVP                 object
# Stadium             object
# City                object
# State               object
# Point Difference     int64
# Referee             object
# Umpire              object
# Head Linesman       object
# Line Judge          object
# Field Judge         object
# Back Judge          object
# Side Judge          object
# dtype: object

# %%
## Display the column names, count of non-null values, and their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              52 non-null     object
#  1   SB                52 non-null     object
#  2   Attendance        52 non-null     int64
#  3   QB  Winner        52 non-null     object
#  4   Coach Winner      52 non-null     object
#  5   Winner            52 non-null     object
#  6   Winning Pts       52 non-null     int64
#  7   QB Loser          52 non-null     object
#  8   Coach Loser       52 non-null     object
#  9   Loser             52 non-null     object
#  10  Losing Pts        52 non-null     int64
#  11  MVP               52 non-null     object
#  12  Stadium           52 non-null     object
#  13  City              52 non-null     object
#  14  State             52 non-null     object
#  15  Point Difference  52 non-null     int64
# ...

# %% [markdown]
# - All collumns appear to have the appropriate data types.

# %% [markdown]
# - All collumns appear to have the appropriate data types.

# %% [markdown]
# ### **Inspect Column Names for Errors**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.(example: cat, Cat, cats)

# %%
## Display column names
df.columns
# Out:
# Index(['Date', 'SB', 'Attendance', 'QB  Winner', 'Coach Winner', 'Winner',
#        'Winning Pts', 'QB Loser', 'Coach Loser', 'Loser', 'Losing Pts', 'MVP',
#        'Stadium', 'City', 'State', 'Point Difference', 'Referee', 'Umpire',
#        'Head Linesman', 'Line Judge', 'Field Judge', 'Back Judge',
#        'Side Judge'],
#       dtype='object')

# %% [markdown]
# - No errors noted.

# %% [markdown]
# ### **Inspect Values for Errors**

# %% [markdown]
# #### **Numeric Columns**

# %% [markdown]
# - **Check for unusual or impossible values.**
#  - Example a weight, or height that is negative in value.
#
# - **Check for Outliers**
#
#  - Outliers are values that are extremely higher or lower than all of the other values in that feature. In general, outliers should not be removed unless you have reason to believe it is an error in the dataset. It is important to investigate outliers, as some models are very sensitive to outliers.

# %%
## Display the descriptive statistics for the non-numeric columns
df.describe(include="number")
# Out:
#           Attendance  Winning Pts  Losing Pts  Point Difference
# count      52.000000    52.000000   52.000000         52.000000
# mean    77455.942308    30.423077   16.384615         14.038462
# std     10373.651925     9.657561    7.306065         10.491755
# min     61946.000000    14.000000    3.000000          1.000000
# 25%     71419.000000    23.750000   10.000000          4.750000
# 50%     74083.000000    30.500000   17.000000         12.000000
# 75%     80280.750000    35.000000   21.000000         19.000000
# max    103985.000000    55.000000   33.000000         45.000000

# %% [markdown]
# #### **Categorical Columns**

# %% [markdown]
# - Check for common syntax errors which may include extra white spaces at the beginning or end of strings or column names.
#
# - Check for typos or inconsistencies in strings that need to be fixed.(example: cat, Cat, cats)

# %%
# Create a series of the datatypes
data_types = df.dtypes
# Create a filter to select only the object datatypes
object_data_types = data_types[(data_types == "object")]
# Display the series of object datatypes
object_data_types
# Out:
# Date             object
# SB               object
# QB  Winner       object
# Coach Winner     object
# Winner           object
# QB Loser         object
# Coach Loser      object
# Loser            object
# MVP              object
# Stadium          object
# City             object
# State            object
# Referee          object
# Umpire           object
# Head Linesman    object
# Line Judge       object
# Field Judge      object
# Back Judge       object
# Side Judge       object
# dtype: object

# %%
## Display the index of object datatypes
object_data_types.index
# Out:
# Index(['Date', 'SB', 'QB  Winner', 'Coach Winner', 'Winner', 'QB Loser',
#        'Coach Loser', 'Loser', 'MVP', 'Stadium', 'City', 'State', 'Referee',
#        'Umpire', 'Head Linesman', 'Line Judge', 'Field Judge', 'Back Judge',
#        'Side Judge'],
#       dtype='object')

# %%
for column in object_data_types.index:
    # Display the unique values from the column
    print(column)
    print(df[column].unique())
    print('\n')
# Out:
# Date
# ['15-Jan-67' '14-Jan-68' '12-Jan-69' '11-Jan-70' '17-Jan-71' '16-Jan-72'
#  '14-Jan-73' '13-Jan-74' '12-Jan-75' '18-Jan-76' '9-Jan-77' '15-Jan-78'
#  '21-Jan-79' '20-Jan-80' '25-Jan-81' '24-Jan-82' '30-Jan-83' '22-Jan-84'
#  '20-Jan-85' '26-Jan-86' '25-Jan-87' '31-Jan-88' '22-Jan-89' '28-Jan-90'
#  '27-Jan-91' '26-Jan-92' '31-Jan-93' '30-Jan-94' '29-Jan-95' '28-Jan-96'
#  '26-Jan-97' '25-Jan-98' '31-Jan-99' '30-Jan-00' '28-Jan-01' '3-Feb-02'
#  '26-Jan-03' '1-Feb-04' '6-Feb-05' '5-Feb-06' '4-Feb-07' '3-Feb-08'
#  '1-Feb-09' '7-Feb-10' '6-Feb-11' '5-Feb-12' '3-Feb-13' '2-Feb-14'
#  '1-Feb-15' '7-Feb-16' '5-Feb-17' '4-Feb-18']
#
#
# SB
# ['I' 'II' 'III' 'IV' 'V' 'VI' 'VII' 'VIII' 'IX' 'X' 'XI' 'XII' 'XIII'
#  'XIV' 'XV' 'XVI' 'XVII' 'XVIII' 'XIX' 'XX' 'XXI' 'XXII' 'XXIII' 'XXIV'
#  'XXV' 'XXVI' 'XXVII' 'XXVIII' 'XXIX' 'XXX' 'XXXI' 'XXXII' 'XXXIII'
#  'XXXIV' 'XXXV' 'XXXVI' 'XXXVII' 'XXXVIII' 'XXXIX' 'XL' 'XLI' 'XLII'
# ...

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# - We could use .info() to see if there are any missing values, however it is best practice to use .isna()

# %%
## Display the total number of missing values
print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 37 missing values.

# %%
## Display the count of missing values by column
print(df.isna().sum())
# Out:
# Date                 0
# SB                   0
# Attendance           0
# QB  Winner           0
# Coach Winner         0
# Winner               0
# Winning Pts          0
# QB Loser             0
# Coach Loser          0
# Loser                0
# Losing Pts           0
# MVP                  0
# Stadium              0
# City                 0
# State                0
# Point Difference     0
# Referee              4
# Umpire               4
# Head Linesman        5
# Line Judge           4
# Field Judge          4
# Back Judge           4
# Side Judge          12
# dtype: int64

# %%
## Display the percentage of missing values by column
print(df.isna().sum()/len(df)*100)
# Out:
# Date                 0.000000
# SB                   0.000000
# Attendance           0.000000
# QB  Winner           0.000000
# Coach Winner         0.000000
# Winner               0.000000
# Winning Pts          0.000000
# QB Loser             0.000000
# Coach Loser          0.000000
# Loser                0.000000
# Losing Pts           0.000000
# MVP                  0.000000
# Stadium              0.000000
# City                 0.000000
# State                0.000000
# Point Difference     0.000000
# Referee              7.692308
# Umpire               7.692308
# Head Linesman        9.615385
# Line Judge           7.692308
# Field Judge          7.692308
# Back Judge           7.692308
# Side Judge          23.076923
# dtype: float64

# %%
## Diplays the first (2) rows with nan values
df[df.isna().any(axis = 1)].head(2)
# Out:
#         Date  SB  Attendance  QB  Winner    Coach Winner             Winner  \
# 0  15-Jan-67   I       61946  Bart Starr  Vince Lombardi  Green Bay Packers
# 1  14-Jan-68  II       75546  Bart Starr  Vince Lombardi  Green Bay Packers
#
#    Winning Pts         QB Loser Coach Loser               Loser  ...  \
# 0           35       Len Dawson  Hank Stram  Kansas City Chiefs  ...
# 1           33  Daryle Lamonica  John Rauch     Oakland Raiders  ...
#
#           City       State Point Difference Referee Umpire  Head Linesman  \
# 0  Los Angeles  California               25     NaN    NaN            NaN
# 1        Miami     Florida               19     NaN    NaN            NaN
#
#   Line Judge Field Judge Back Judge Side Judge
# 0        NaN         NaN        NaN        NaN
# 1        NaN         NaN        NaN        NaN
#
# [2 rows x 23 columns]

# %% [markdown]
# #### **Missing Value Option Justifications**

# %% [markdown]
# ##### **Numeric Columns**
# - **Drop the column**
#  - con: This would result in a significant loss of data.
#  - +50% missing values per row would be significant enough to justify this option.
#
# - **Drop rows with missing values**
#  - con: This would result in a significant loss of data.
#  - +5% missing values per column would too great to justify this option, however -5% missing values would justify this option.
#
# - **Impute missing values using the 'mean' value of the column**
#  - pro: This typically works well with small numeric datasets.
#  - con: This can introduce bias and is affected by skew and outliers more than the 'median' value.
#  - con: This will not factor correlations between features.
#
# - **Impute missing values using the 'median' value of the column**
#  - pro: This typically works well with small numeric datasets.
#  - pro: This is less affected by outliers than strategy = 'mean'.
#  - con: This will not factor correlations between features.

# %% [markdown]
# ##### **Categorical Columns**
# - **Drop the column**
#  - con: This would result in a significant loss of data.
#  - +50% missing values per row would be significant enough to justify this option.
#
# - **Drop rows with missing values**
#  - con: This would result in a significant loss of data.
#  - +5% missing values per column would too great to justify this option, however -5% missing values would justify this option.
#
# - **Replace missing values with the value 'Unknown'**
#  - pro: This typically will not create bias in favor of a specific label or class.
#  - con: This will not factor correlations between features.
#
# - **Impute missing values using the most frequent value, 'mode', value of the column**
#  - pro: This typically works well with small numeric datasets.
#  - con: This may create bias in favor of a specific label or class.
#  - con: This will not factor correlations between features.

# %% [markdown]
# #### **'Referee' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df.Referee.fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Umpire' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df.Umpire.fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Head Linesman' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df['Head Linesman'].fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Line Judge' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df['Line Judge'].fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Field Judge' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df['Field Judge'].fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Back Judge' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df['Back Judge'].fillna(value = 'Unknown', inplace=True)

# %% [markdown]
# #### **'Side Judge' Column**

# %% [markdown]
# - **Missing 7.69% of values**
# - **Strategy:**
#  - Replace the missing values with the value "Unknown"
# - **Justification**
#   - This typically will not create bias in favor of a specific label or class.

# %%
# Replace missing values with 'Unknown'
df['Side Judge'].fillna(value = 'Unknown', inplace=True)

# %%
## Display the total number of missing values
print(f'There are {df.isna().sum().sum()} missing values.')
# Out:
# There are 0 missing values.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Data types
#
# You want your data to all be correct data types. There may be errors in your data causing numeric types to be read in as objects or dates that need to be converted to datetime objects. Additionally, we may want to convert our categorical variables to numbers.
#
# **Check the datatypes & validate that they are what they should be. The `Date` column should be a DateTime type - fix this using `pd.to_datetime()` if is not the case!**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 0 to 51
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              52 non-null     object
#  1   SB                52 non-null     object
#  2   Attendance        52 non-null     int64
#  3   QB  Winner        52 non-null     object
#  4   Coach Winner      52 non-null     object
#  5   Winner            52 non-null     object
#  6   Winning Pts       52 non-null     int64
#  7   QB Loser          52 non-null     object
#  8   Coach Loser       52 non-null     object
#  9   Loser             52 non-null     object
#  10  Losing Pts        52 non-null     int64
#  11  MVP               52 non-null     object
#  12  Stadium           52 non-null     object
#  13  City              52 non-null     object
#  14  State             52 non-null     object
#  15  Point Difference  52 non-null     int64
# ...

# %%
data_types = df.dtypes
data_types
# Out:
# Date                object
# SB                  object
# Attendance           int64
# QB  Winner          object
# Coach Winner        object
# Winner              object
# Winning Pts          int64
# QB Loser            object
# Coach Loser         object
# Loser               object
# Losing Pts           int64
# MVP                 object
# Stadium             object
# City                object
# State               object
# Point Difference     int64
# Referee             object
# Umpire              object
# Head Linesman       object
# Line Judge          object
# Field Judge         object
# Back Judge          object
# Side Judge          object
# dtype: object

# %%
str_cols = data_types[ data_types=='object']
str_cols
# Out:
# Date             object
# SB               object
# QB  Winner       object
# Coach Winner     object
# Winner           object
# QB Loser         object
# Coach Loser      object
# Loser            object
# MVP              object
# Stadium          object
# City             object
# State            object
# Referee          object
# Umpire           object
# Head Linesman    object
# Line Judge       object
# Field Judge      object
# Back Judge       object
# Side Judge       object
# dtype: object

# %%
str_cols.index
# Out:
# Index(['Date', 'SB', 'QB  Winner', 'Coach Winner', 'Winner', 'QB Loser',
#        'Coach Loser', 'Loser', 'MVP', 'Stadium', 'City', 'State', 'Referee',
#        'Umpire', 'Head Linesman', 'Line Judge', 'Field Judge', 'Back Judge',
#        'Side Judge'],
#       dtype='object')

# %%
df[str_cols.index]
# Out:
#          Date       SB                    QB  Winner     Coach Winner  \
# 0   15-Jan-67        I                    Bart Starr   Vince Lombardi
# 1   14-Jan-68       II                    Bart Starr   Vince Lombardi
# 2   12-Jan-69      III                    Joe Namath      Weeb Ewbank
# 3   11-Jan-70       IV   Len Dawson, Mike Livingston       Hank Stram
# 4   17-Jan-71        V  Earl Morrall , Johnny Unitas   Don McCafferty
# 5   16-Jan-72       VI                Roger Staubach       Tom Landry
# 6   14-Jan-73      VII                    Bob Griese        Don Shula
# 7   13-Jan-74     VIII                    Bob Griese        Don Shula
# 8   12-Jan-75       IX                Terry Bradshaw       Chuck Noll
# 9   18-Jan-76        X                Terry Bradshaw       Chuck Noll
# 10   9-Jan-77       XI                 Kenny Stabler      John Madden
# 11  15-Jan-78      XII                Roger Staubach       Tom Landry
# ...

# %%
# Run this after showing the datetime error that you get.
df.loc[0, 'Date'] = '1967-01-15'
df.loc[1, 'Date'] = '1968-01-14'
df.loc[2, 'Date'] = '1969-01-12'
df.loc[3, 'Date'] = '1970-01-11'

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#          Date       SB  Attendance                    QB  Winner  \
# 0  1967-01-15        I       61946                    Bart Starr
# 1  1968-01-14       II       75546                    Bart Starr
# 2  1969-01-12      III       75389                    Joe Namath
# 3  1970-01-11       IV       80562   Len Dawson, Mike Livingston
# 4  2071-01-17        V       79204  Earl Morrall , Johnny Unitas
# 5  2072-01-16       VI       81023                Roger Staubach
# 6  1973-01-14      VII       90182                    Bob Griese
# 7  1974-01-13     VIII       71882                    Bob Griese
# 8  1975-01-12       IX       80997                Terry Bradshaw
# 9  1976-01-18        X       80187                Terry Bradshaw
# 10 1977-01-09       XI      103438                 Kenny Stabler
# 11 1978-01-15      XII       76400                Roger Staubach
# 12 1979-01-21     XIII       79484                Terry Bradshaw
# ...

# %% [markdown]
# Pandas is usually pretty good at converting date times.  However, when the year is 2 digits it can be ambiguous and Pandas may choose the wrong century.
#
# Check if this happened and if so, fix it.  Don't forget the `df.loc()` method.
#
# You may have to convert it to a datetime again.

# %%
df.dtypes
# Out:
# Date                datetime64[ns]
# SB                          object
# Attendance                   int64
# QB  Winner                  object
# Coach Winner                object
# Winner                      object
# Winning Pts                  int64
# QB Loser                    object
# Coach Loser                 object
# Loser                       object
# Losing Pts                   int64
# MVP                         object
# Stadium                     object
# City                        object
# State                       object
# Point Difference             int64
# Referee                     object
# Umpire                      object
# Head Linesman               object
# Line Judge                  object
# Field Judge                 object
# Back Judge                  object
# Side Judge                  object
# dtype: object

# %%
df['Date'].dt.year
# Out:
# 0     1967
# 1     1968
# 2     1969
# 3     1970
# 4     2071
# 5     2072
# 6     1973
# 7     1974
# 8     1975
# 9     1976
# 10    1977
# 11    1978
# 12    1979
# 13    1980
# 14    1981
# 15    1982
# 16    1983
# 17    1984
# 18    1985
# 19    1986
# 20    1987
# 21    1988
# 22    1989
# 23    1990
# 24    1991
# 25    1992
# 26    1993
# 27    1994
# 28    1995
# 29    1996
# 30    1997
# 31    1998
# 32    1999
# 33    2000
# 34    2001
# 35    2002
# 36    2003
# 37    2004
# 38    2005
# 39    2006
# 40    2007
# 41    2008
# 42    2009
# 43    2010
# 44    2011
# 45    2012
# 46    2013
# 47    2014
# 48    2015
# 49    2016
# 50    2017
# 51    2018
# Name: Date, dtype: int64

# %%
data_types = df.dtypes
str_cols = data_types[ data_types=='object'].index
str_cols
# Out:
# Index(['SB', 'QB  Winner', 'Coach Winner', 'Winner', 'QB Loser', 'Coach Loser',
#        'Loser', 'MVP', 'Stadium', 'City', 'State', 'Referee', 'Umpire',
#        'Head Linesman', 'Line Judge', 'Field Judge', 'Back Judge',
#        'Side Judge'],
#       dtype='object')

# %% [markdown]
# ## Syntax or spelling errors
#
# Common syntax errors include extra white spaces at the beginning or end of strings or column names.
#
# There may also be typos or inconsistencies in strings that need to be fixed. For example, if a state name is spelled out in one row and the abbreviation is used in another, we need to ensure consistency.
#
# **Check for any inconsistencies in the strings of the `State` column and fix them.**
#
# Don't forget the `df.replace()` method

# %%
str_cols
# Out:
# Index(['SB', 'QB  Winner', 'Coach Winner', 'Winner', 'QB Loser', 'Coach Loser',
#        'Loser', 'MVP', 'Stadium', 'City', 'State', 'Referee', 'Umpire',
#        'Head Linesman', 'Line Judge', 'Field Judge', 'Back Judge',
#        'Side Judge'],
#       dtype='object')

# %%
# sb.select_dtypes('object')

# %%
for col in str_cols:
    print(f'- {col}:')
    print(df[col].value_counts(dropna=False))
    print("\n\n")
# Out:
# - SB:
# I          1
# II         1
# XXIX       1
# XXX        1
# XXXI       1
# XXXII      1
# XXXIII     1
# XXXIV      1
# XXXV       1
# XXXVI      1
# XXXVII     1
# XXXVIII    1
# XXXIX      1
# XL         1
# XLI        1
# XLII       1
# XLIII      1
# XLIV       1
# XLV        1
# XLVI       1
# XLVII      1
# XLVIII     1
# XLIX       1
# L          1
# LI         1
# XXVIII     1
# XXVII      1
# XXVI       1
# XIII       1
# III        1
# IV         1
# V          1
# VI         1
# VII        1
# VIII       1
# IX         1
# X          1
# XI         1
# XII        1
# XIV        1
# XXV        1
# XV         1
# XVI        1
# XVII       1
# XVIII      1
# XIX        1
# XX         1
# XXI        1
# XXII       1
# XXIII      1
# XXIV       1
# LII        1
# Name: SB, dtype: int64
#
#
#
# - QB  Winner:
# Tom Brady                       5
# Terry Bradshaw                  4
# Joe Montana                     3
# Troy Aikman                     3
# ...

# %%
df['Referee'].unique()
# Out:
# array(['Unknown', 'Norm Schachter', 'Jim Tunney', 'Tom Bell',
#        'Ben Dreith', 'Bernie Ulman', 'Pat Haggerty', 'Fred Silva',
#        'Jerry Markbreit', 'Gene Barth', 'Red Cashion', 'Bob McElwee',
#        'Jerry Seeman', 'Dick Jorgensen', 'Dick Hantak', 'Gerald Austin',
#        'Ed Hochuli', 'Bernie Kukar', 'Bill Carollo', 'Terry McAulay',
#        'Bill Leavy', 'Tony Corrente', 'Mike Carey[3]', 'Scott Green[4]',
#        'Walt Anderson[5]', 'John Parry', 'Jerome Boger', 'Bill Vinovich',
#        'Clete Blakeman', 'Carl Cheffers', 'Gene Steratore'], dtype=object)

# %%
df.nunique()
# Out:
# Date                52
# SB                  52
# Attendance          52
# QB  Winner          33
# Coach Winner        40
# Winner              22
# Winning Pts         28
# QB Loser            40
# Coach Loser         39
# Loser               26
# Losing Pts          21
# MVP                 44
# Stadium             31
# City                20
# State               11
# Point Difference    28
# Referee             31
# Umpire              27
# Head Linesman       28
# Line Judge          29
# Field Judge         36
# Back Judge          32
# Side Judge          28
# dtype: int64

# %%
df['Coach Winner'] = df['Coach Winner'].str.replace('_','')
df['Coach Loser'] = df['Coach Loser'].str.replace('_','')

# %%
df['State'] = df['State'].replace('FL', 'Florida')
df['State'].value_counts()
# Out:
# Florida       15
# California    12
# Louisiana     10
# Texas          4
# Arizona        3
# Michigan       2
# Minnesota      2
# Georgia        2
# Indiana        1
# New Jersey     1
# Name: State, dtype: int64

# %%
repl_map ={'FL':'Florida'}

df['State'] = df['State'].replace(repl_map)#'FL','Florida')
df['State'].value_counts()
# Out:
# Florida       15
# California    12
# Louisiana     10
# Texas          4
# Arizona        3
# Michigan       2
# Minnesota      2
# Georgia        2
# Indiana        1
# New Jersey     1
# Name: State, dtype: int64

# %%
df_clean = df.dropna(subset=['Referee', 'Umpire', 'Head Linesman', 'Line Judge', 'Field Judge',
       'Back Judge'],how='all')

# %% [markdown]
# # Exploratory Data Analysis - Questions to Answer

# %% [markdown]
# - For each question, display on the columns required to answer the question.

# %% [markdown]
# ### Q1. Which 3 Superbowl #'s/years had the largest attendance?

# %%
df.sort_values('Attendance',ascending=False).head(3)[['SB','Date','Attendance']]
# Out:
#       SB       Date  Attendance
# 13   XIV 1980-01-20      103985
# 16  XVII 1983-01-30      103667
# 10    XI 1977-01-09      103438

# %% [markdown]
# - A1: Super Bowl XIV (1980), XVII (1983) and XI (1977) had the highest attendance.

# %% [markdown]
# ### Q2. Which Stadiums hosted the Superbowl with the largest attendance?

# %%
df.sort_values('Attendance',ascending=False).head(3)[['SB','Date','Attendance','Stadium']]
# Out:
#       SB       Date  Attendance    Stadium
# 13   XIV 1980-01-20      103985  Rose Bowl
# 16  XVII 1983-01-30      103667  Rose Bowl
# 10    XI 1977-01-09      103438  Rose Bowl

# %% [markdown]
# - A2: The Rose Bowl hosted all 3 SuperBowls with the highest attendance.

# %% [markdown]
# ### Q3: What city has hosted the most of superbowls? How many?

# %%
df['City'].value_counts()
# Out:
# New Orleans        10
# Miami               5
# Pasadena            5
# Miami Gardens       5
# Tampa               4
# Houston             3
# San Diego           3
# Los Angeles         2
# Glendale            2
# Atlanta             2
# Minneapolis         2
# Palo Alto           1
# Tempe               1
# Jacksonville        1
# Detroit             1
# Pontiac             1
# Arlington           1
# Indianapolis        1
# East Rutherford     1
# Santa Clara         1
# Name: City, dtype: int64

# %% [markdown]
# - A3: New Orleans has hosted the most superbowls (10)

# %% [markdown]
# ### Q4: Of all of the superbowls hosted in the city from Q3, which SB # had the lowest attendance?

# %%
no_sbs = df.loc[df['City']=='New Orleans']
no_sbs.sort_values('Attendance').head(3)[['Date','SB','Attendance']]
# Out:
#          Date     SB  Attendance
# 46 2013-02-03  XLVII       71024
# 30 1997-01-26   XXXI       72301
# 23 1990-01-28   XXIV       72919

# %% [markdown]
# - A4: SuperBowl XLVII in 2013 had the lowest attendance.

# %% [markdown]
# ### Q5: What is the average point difference between teams, for each City? Which city has the highest average Point Difference?

# %%
df.groupby('City').mean()['Point Difference']
# Out:
# <ipython-input-107-9b932a971d2a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City').mean()['Point Difference']
# City
# Arlington           6.000000
# Atlanta            12.000000
# Detroit            11.000000
# East Rutherford    35.000000
# Glendale            3.500000
# Houston             8.666667
# Indianapolis        4.000000
# Jacksonville        3.000000
# Los Angeles        16.000000
# Miami               7.800000
# Miami Gardens      13.600000
# Minneapolis        10.500000
# New Orleans        18.200000
# Palo Alto          22.000000
# Pasadena           18.800000
# Pontiac             5.000000
# San Diego          22.000000
# Santa Clara        14.000000
# Tampa              15.250000
# Tempe              10.000000
# Name: Point Difference, dtype: float64

# %%
df.groupby('City').mean()['Point Difference'].sort_values(ascending=False)
# Out:
# <ipython-input-108-9698a7d99719>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('City').mean()['Point Difference'].sort_values(ascending=False)
# City
# East Rutherford    35.000000
# San Diego          22.000000
# Palo Alto          22.000000
# Pasadena           18.800000
# New Orleans        18.200000
# Los Angeles        16.000000
# Tampa              15.250000
# Santa Clara        14.000000
# Miami Gardens      13.600000
# Atlanta            12.000000
# Detroit            11.000000
# Minneapolis        10.500000
# Tempe              10.000000
# Houston             8.666667
# Miami               7.800000
# Arlington           6.000000
# Pontiac             5.000000
# Indianapolis        4.000000
# Glendale            3.500000
# Jacksonville        3.000000
# ...

# %% [markdown]
# - A5: East Rutherford had the highest average point differnce between teams.
